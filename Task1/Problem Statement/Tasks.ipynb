# %%
#Task 1
#import numpy 
import numpy as np

# Define the 4 matrices as A,B,C,D
A = np.array([[1, 2, 3], [4, 5, 6]])
B = np.array([[1, 6, 0, 5, 6], [1, 9, 7, 3, 34], [2, 0, 9, 1, 19]])
C = np.array([[9, 2],[3, 3],[4, 5],[10, 6],[82,11]])
D = np.array([[2, 42, 3], [5, 0, 6],[5, 8, 3]])

# Print the 4 matrices
print("The matrices are as follows: ")
print(A)
print(B)
print(C)
print(D)
# Find the Dot Product of matrices
dot1=np.dot(A,D)
dot2=np.dot(dot1,B)
dot3=np.dot(dot2,C)
print("The dot product of the given matrices is: ",dot3)

#ValueError
#A=[[1,2,3],[4,5,6]]
#B=[[1,2],[5,3],[4,5]]
def is_compatible(A, B):
    r1=0 
    c1=0
    r2=0
    c2=0
    cnt=0
    for i in A:
        if cnt==0:
          for j in i:
            c1+=1
        r1+=1
        cnt+=1
    for i in B:
        if cnt==r1:
          for j in i:
            c2+=1
        r2+=1
        cnt+=1
    if c1==r2:
        return np.dot(A,B)
    else:
        return ("Dimension Error!!")
print("Dot product of matrices A and B: ",is_compatible(A,B))
print("Dot product of matrices C and D: ",is_compatible(C,D))
#Task 2
def up_down(rounds):
   score=0 
   for i in range(rounds):
        if score>=30 or score<=-30 :
            break
        else:
           user=int(input("Enter your choice of number between 1 and 12"))
           ref=int(np.random.rand() * 12) + 1
           if ref < 7 :
              if user<7:
                 score+=user
              else:
                 score-=user
           elif ref==7:
              if user==7:
                 score+=14
              else:
                 score-=user
           else:
              if user>7:
                 score+=user
              else:
                 score-=user
   print("Game is over")
   
   if score>=30:
      print("Congratulations! You Win!")
   elif score<=-30:
      print("You Lost")
   print("Your score is: ",score)
n=int(input("Enter the number of rounds you want to play: "))
up_down(n)
